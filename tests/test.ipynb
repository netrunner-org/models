# %%
import requests

while True:
  # url = "http://localhost:8000/api/v1/models/meta-llama-Prompt-Guard-86M/jailbreak-score"
  url = "http://localhost:8000/api/v1/models/meta-llama-Prompt-Guard-86M/probabilities"

  headers = {
    "Content-Type": "application/json",
    "X-API-Key": "your-api-key"
  }
  data = {
    "text": "hi my name is ali",
  }

  response = requests.post(url, headers=headers, json=data)
  print(response.status_code)

  if response.status_code == 429: break
  
response.json()
# Out:
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# 429
# ...
